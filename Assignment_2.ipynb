# %%
Q1). What are the two values of the Boolean data type? How do you write them?

Solution :- The two values of Boolean data type are True and False.
           We have to write First letter in capital for each boolean value like True and False.

# %%
Q2). What are the three different types of Boolean operators?

Solution:- Three different types of boolean operators are 'and','or','not'

# %%
Q3). Make a list of each Boolean operator's truth tables 
(i.e. every possible combination of Boolean values for the operator and what it evaluate ).

Solution :-
    Operator and     input1   input2  |  Result  |   
                     True     True    |  True    |   
                     True     False   |  False   |
                     False    True    |  False   |
                     False    False   |  False   |
    This and operator checks both value are True then only it is True otherwise its False.

                    
    Operator or      input1   input2  |  Result  |
                     True     True    |  True    |
                     True     False   |  True    |
                     False    True    |  True    |
                     False    False   |  False   |
    This or operator gives True when both the values or one of the value is True otherwise gives False.
                    
    Operator not     input1     |  Result  |
                     True       |  False   |
                     False      |  True    |
   This not operator gives True when input is False its vice versa.

# %%
Q4). What are the values of the following expressions?
1) (5 > 4) and (3 == 5)
2) not (5 > 4)
3) (5 > 4) or (3 == 5)
4) not ((5 > 4) or (3 == 5))
5) (True and True) and (True == False)
6) (not False) or (not True)

Solution :- 
    1) (5 > 4) and (3 == 5)
    It will give False because in the expression (5>4) will give True but (3==5) will give False.
    So we know how the and operator works if one of the value is False the whole is False.
    
    2) not (5 > 4)
    It will give False because in the expression (5>4) will give True but not operator will convert 
    that True to False.
    
    3) (5 > 4) or (3 == 5)
    It will give True as (5>4) will give True and (3==5) will give False but or operator works like 
    if one of the value is True the it is True.
    
    4) not ((5 > 4) or (3 == 5))
    It will give result as False because (5>4) will give True and (3==5) will give False or operator will 
    make it True then the not operator will change it to False.
    
    5) (True and True) and (True == False)
    It will give False as (True and True) will give True and (True == False) will give False and 'and' operator 
    will make it False as one value is False.
    
    6) (not False) or (not True)
    It will give True as (not False) will be True and (not True) will be False but or operator will make it True.

# %%
Q5). What are the six comparison operators?

Solution :-
    1) < (less than operator)
    2) > (greater than operator)
    3) <= (less than equal to operator)
    4) >= (greater than equal to operator)
    5) == (equal to operator which checks the value at left an right if equal returns True)
    6) != (not equal to operator which checks value at left and right if not equal then returns False)

# %%
Q6). How do you tell the difference between the equal to and assignment operators?
Describe a condition and when you would use one.

Solution :-
    Equal to operator is basically (==) and assignment operator is just with one equal sign(=).
    Equal to operator is used to check both the values at left and right if both are same then return
    True else return False. Assignment operator is used to simply assign a value to variable(reference).
    Example Equal to
    rank = 5
    if(rank == 1):
        print("You are the Topper")
    
    Here, we are comparing the value in the variable rank with 1 if it is equal then return True and enter 
    the if block and print the statement.
    
    Example Assignment
    a=1
    b=2
    c=a+b
    Here, one equal is use just to assign the value to the variable.

# %%
Q7). Identify the three blocks in this code:
spam = 0
if spam == 10:
print('eggs')
if spam > 5:
print('bacon')
else:
print('ham')
print('spam')
print('spam')

Solution :- 

spam = 0
if spam == 10 :       -----> First block(if)
    print('eggs')
if spam > 5 :         -----> Second block(if)
    print('bacon')
else:                 -----> third block(else)
    print('ham')
    print('spam')
    print('spam')

# %%
Q8). Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, 
and prints Greetings! if anything else is stored in spam.

Solution :-

spam=int(input())    
if spam==1:
    print("Hello")
elif spam==2:
    print("Howdy")
else:
    print("Greetings!")

# %%
Q9).If your programme is stuck in an endless loop, what keys you’ll press?

Solution :-
    Like for my python coding i have been using VS code so in that i have many time used it 
    like key I press is ' ctrl + c ' to stop an endless loop execution. In jupyter notebook I used
    interrupt in kernel.

# %%
Q10). How can you tell the difference between break and continue?

Solution :-
    break is used to break the flow of the program in a loop.when break is used it breaks the 
    nearest loop. continue is used to continue the program like dont go for further steps in that loop 
    after seeing continue, just jump to next iteration 
    most often both of these are used with if block.
    break is used to stop the iteration in an endless loop but continue cannot do this.
    Example.
    i=0
    while(True):
        print("infinite")
        i=+1
        if (i==9):
            break
    Here it is actually a endless loop but in if condition when value of i = 9 at that time it breaks 
    the while loop.
    
    Example
    i=0
    while i<9:
        i+=1
        if i==3:
            continue
        print(i)
    Here, it will print values from 1 to 9 except value 3 here after continue it again goes to
    while condition.

# %%
Q11). In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?

Solution :-
    like to say logically there is no difference between range(10), range(0, 10), and range(0, 10, 1)
    range(10) produces number ranging from 0 to 9.
    range(0,10),range(0,10,1) also produces same numbers
    difference is only about arguments it takes.It basically takes 3 aruguments
    first is starting number for our range,second is the end point of the range but that number is 
    not included and third is the step argument.
    range(0,10,1) here start is 0 and end is 9 as 10 is not included and step argument is 1
    In range(0,10) here start is 0 and end is 9 here no step argument mentioned but by default 
    step argument is 1,In range(10) here start argument is not given so by default it takes start as 
    0 then end is 9 and step argument is again by default 1.

# %%
Q12). Write a short program that prints the numbers 1 to 10 using a for loop. 
Then write an equivalent program that prints the numbers 1 to 10 using a while loop.

Solution :-
1) For loop
for i in range(1,11):
    print(i)
    
2) While loop
i=1
while i <= 10:
    print(i)
    i+=1

# %%
Q13). If you had a function named bacon() inside a module named spam, 
how would you call it after importing spam?

Solution :- Like first we have to import module spam and then using spam we have to call bacon() function
    
Example
import spam
spam.bacon()

##### otherway is by using alias

import spam as s
s.bacon()
